# %%
import os
files = os.listdir(os.getcwd())
for nb in sorted([i for i in files if i.endswith('.ipynb')])[1:]:
    os.system(f'jupyter nbconvert --to notebook --inplace --execute {nb}')
os.system('shutdown')
# Out:
# [NbConvertApp] Converting notebook 01OURS_TN.ipynb to notebook
# [NbConvertApp] Writing 539049 bytes to 01OURS_TN.ipynb
# [NbConvertApp] Converting notebook 01OURS_TN_MMPD.ipynb to notebook
# [NbConvertApp] Writing 538968 bytes to 01OURS_TN_MMPD.ipynb
# [NbConvertApp] Converting notebook 01OURS_WOTN.ipynb to notebook
# [NbConvertApp] Writing 539097 bytes to 01OURS_WOTN.ipynb
# [NbConvertApp] Converting notebook 01OURS_WOTN_MMPD.ipynb to notebook
# [NbConvertApp] Writing 539021 bytes to 01OURS_WOTN_MMPD.ipynb
# [NbConvertApp] Converting notebook 02TSCAN.ipynb to notebook
# [NbConvertApp] Writing 535743 bytes to 02TSCAN.ipynb
# [NbConvertApp] Converting notebook 02TSCAN_MMPD.ipynb to notebook
# [NbConvertApp] Writing 535181 bytes to 02TSCAN_MMPD.ipynb
# [NbConvertApp] Converting notebook 02TSCAN_TN.ipynb to notebook
# [NbConvertApp] Writing 534612 bytes to 02TSCAN_TN.ipynb
# [NbConvertApp] Converting notebook 02TSCAN_TN_MMPD.ipynb to notebook
# [NbConvertApp] Writing 534529 bytes to 02TSCAN_TN_MMPD.ipynb
# [NbConvertApp] Converting notebook 03PhysNet.ipynb to notebook
# [NbConvertApp] Writing 541435 bytes to 03PhysNet.ipynb
# [NbConvertApp] Converting notebook 03PhysNetTN.ipynb to notebook
# [NbConvertApp] Writing 541580 bytes to 03PhysNetTN.ipynb
# [NbConvertApp] Converting notebook 03PhysNetTN_MMPD.ipynb to notebook
# [NbConvertApp] Writing 540906 bytes to 03PhysNetTN_MMPD.ipynb
# [NbConvertApp] Converting notebook 03PhysNet_MMPD.ipynb to notebook
# [NbConvertApp] Writing 540945 bytes to 03PhysNet_MMPD.ipynb
# [NbConvertApp] Converting notebook 04EfficientPhys.ipynb to notebook
# [NbConvertApp] Writing 546337 bytes to 04EfficientPhys.ipynb
# [NbConvertApp] Converting notebook 04EfficientPhysTN.ipynb to notebook
# [NbConvertApp] Writing 545948 bytes to 04EfficientPhysTN.ipynb
# [NbConvertApp] Converting notebook 04EfficientPhysTN_MMPD.ipynb to notebook
# [NbConvertApp] Writing 542627 bytes to 04EfficientPhysTN_MMPD.ipynb
# [NbConvertApp] Converting notebook 04EfficientPhys_MMPD.ipynb to notebook
# [NbConvertApp] Writing 543023 bytes to 04EfficientPhys_MMPD.ipynb
# [NbConvertApp] Converting notebook 05PhysFormer.ipynb to notebook
